# %%
from owlready2 import *

# %%
onto = get_ontology("file:////home/nab/Niklas/TEM-lactamase/CARD_Data_Ontologies/aro.owl").load()

# %%
from rdflib import Graph, Namespace, RDF, RDFS, OWL

g = Graph()
g.parse("/home/nab/Niklas/TEM-lactamase/CARD_Data_Ontologies/aro.owl")

# Define the namespaces
OWL_NS = Namespace("http://www.w3.org/2002/07/owl#")
RDF_NS = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
RDFS_NS = Namespace("http://www.w3.org/2000/01/rdf-schema#")


for s, p, o in g.triples((None, RDF.type, OWL.ObjectProperty)):
    class_name = str(s)
    print(class_name)

for s, p, o in g.triples((None, RDFS.subClassOf, None)):
    subclass = str(s)
    superclass = str(o)

    print(f"{subclass} is a subclass of {superclass}")
# Out:
# http://purl.obolibrary.org/obo/RO_0002312
# http://purl.obolibrary.org/obo/RO_0012006
# http://purl.obolibrary.org/obo/RO_regulates
# http://purl.obolibrary.org/obo/RO_#confers_resistance_to_antibiotic
# http://purl.obolibrary.org/obo/RO_#confers_resistance_to_drug_class
# http://purl.obolibrary.org/obo/RO_#derives_from
# http://purl.obolibrary.org/obo/RO_#has_part
# http://purl.obolibrary.org/obo/RO_#is_a
# http://purl.obolibrary.org/obo/RO_#part_of
# http://purl.obolibrary.org/obo/RO_#participates_in
# http://purl.obolibrary.org/obo/RO_#targeted_by
# http://purl.obolibrary.org/obo/RO_#targeted_by_antibiotic
# http://purl.obolibrary.org/obo/ARO_0000000 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_0000001 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_0000016 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_0000017 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_0000026 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3000003 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3000007 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3000034 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3000050 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3000053 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3000079 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3000081 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3000103 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3000157 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3000171 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3000282 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3000387 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3000527 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3000551 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3000670 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3000707 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3001219 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3001318 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3003401 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3003956 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3004115 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3004116 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3004491 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3005163 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3005167 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3005168 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3005169 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3005170 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3005171 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3005172 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3005386 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007034 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007149 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007150 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007151 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007152 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007153 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007154 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007155 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007156 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007157 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007158 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007159 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007160 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007161 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007162 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007163 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007164 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007166 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007177 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007495 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007496 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007497 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007498 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007540 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007560 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_3007773 is a subclass of http://purl.obolibrary.org/obo/ARO_1000003
# http://purl.obolibrary.org/obo/ARO_0000002 is a subclass of http://purl.obolibrary.org/obo/ARO_3000185
# http://purl.obolibrary.org/obo/ARO_3000419 is a subclass of http://purl.obolibrary.org/obo/ARO_3000185
# http://purl.obolibrary.org/obo/ARO_3000507 is a subclass of http://purl.obolibrary.org/obo/ARO_3000185
# http://purl.obolibrary.org/obo/ARO_3004469 is a subclass of http://purl.obolibrary.org/obo/ARO_3000185
# http://purl.obolibrary.org/obo/ARO_3005086 is a subclass of http://purl.obolibrary.org/obo/ARO_3000185
# http://purl.obolibrary.org/obo/ARO_0000002 is a subclass of N3de0e24b89c54d1d940d978e4afd5454
# http://purl.obolibrary.org/obo/ARO_0000003 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_0000005 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_0000007 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_0000013 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_0000021 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_0000024 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_0000035 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_0000037 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_0000038 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_0000039 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_0000040 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_0000049 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_0000052 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3000214 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3000652 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3000653 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3000654 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3000657 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3000658 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3000700 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3000701 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3001294 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3001295 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3001296 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3003675 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3003993 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3007377 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3007378 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3007379 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_3007382 is a subclass of http://purl.obolibrary.org/obo/ARO_0000016
# http://purl.obolibrary.org/obo/ARO_0000004 is a subclass of http://purl.obolibrary.org/obo/ARO_3000007
# http://purl.obolibrary.org/obo/ARO_0000020 is a subclass of http://purl.obolibrary.org/obo/ARO_3000007
# http://purl.obolibrary.org/obo/ARO_3000008 is a subclass of http://purl.obolibrary.org/obo/ARO_3000007
# http://purl.obolibrary.org/obo/ARO_3000276 is a subclass of http://purl.obolibrary.org/obo/ARO_3000007
# http://purl.obolibrary.org/obo/ARO_3003706 is a subclass of http://purl.obolibrary.org/obo/ARO_3000007
# http://purl.obolibrary.org/obo/ARO_3007676 is a subclass of http://purl.obolibrary.org/obo/ARO_3000007
# http://purl.obolibrary.org/obo/ARO_0000006 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_0000027 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_0000057 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_0000065 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3000145 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3000156 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3000158 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3000176 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3000867 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3001221 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3001222 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3001223 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3001224 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3001225 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3001226 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3001227 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3001228 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3001229 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3001230 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3001232 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3001233 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3003701 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3003972 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3007455 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3007457 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3007472 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3007570 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3007760 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3007761 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3007762 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3007763 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3007786 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3007792 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3007793 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3007795 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_3007796 is a subclass of http://purl.obolibrary.org/obo/ARO_0000000
# http://purl.obolibrary.org/obo/ARO_0000008 is a subclass of http://purl.obolibrary.org/obo/ARO_0000044
# http://purl.obolibrary.org/obo/ARO_3004001 is a subclass of http://purl.obolibrary.org/obo/ARO_0000044
# http://purl.obolibrary.org/obo/ARO_3004004 is a subclass of http://purl.obolibrary.org/obo/ARO_0000044
# http://purl.obolibrary.org/obo/ARO_0000009 is a subclass of http://purl.obolibrary.org/obo/ARO_3000034
# http://purl.obolibrary.org/obo/ARO_0000012 is a subclass of http://purl.obolibrary.org/obo/ARO_3000034
# http://purl.obolibrary.org/obo/ARO_3000080 is a subclass of http://purl.obolibrary.org/obo/ARO_3000034
# http://purl.obolibrary.org/obo/ARO_3007139 is a subclass of http://purl.obolibrary.org/obo/ARO_3000034
# http://purl.obolibrary.org/obo/ARO_3007479 is a subclass of http://purl.obolibrary.org/obo/ARO_3000034
# http://purl.obolibrary.org/obo/ARO_3007481 is a subclass of http://purl.obolibrary.org/obo/ARO_3000034
# http://purl.obolibrary.org/obo/ARO_3007687 is a subclass of http://purl.obolibrary.org/obo/ARO_3000034
# http://purl.obolibrary.org/obo/ARO_0000009 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_0000014 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_0000041 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_0000053 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3000199 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3000227 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3000454 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3003997 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3003998 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004020 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004021 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004022 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004023 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004024 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004701 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004702 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004703 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004705 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004707 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004708 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004709 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004710 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004711 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004712 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004713 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004714 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3004724 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3007040 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3007072 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3007145 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3007146 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3007148 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3007364 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3007365 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3007366 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3007382 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3007422 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_3007467 is a subclass of http://purl.obolibrary.org/obo/ARO_3000707
# http://purl.obolibrary.org/obo/ARO_0000010 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_0000031 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3000012 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3000100 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3000159 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3000185 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3000270 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3000381 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3000451 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3000492 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3000519 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3000557 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3000610 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3001207 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3003040 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3003580 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3003768 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3004916 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3007425 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3007429 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_3007610 is a subclass of http://purl.obolibrary.org/obo/ARO_3000000
# http://purl.obolibrary.org/obo/ARO_0000011 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_0000015 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_0000043 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_0000054 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_0000056 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_0000064 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_0000078 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_3000632 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_3000633 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_3000634 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_3000635 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_3000636 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_3000637 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_3000638 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_3000639 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_3000705 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_3000706 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_3000761 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_3003831 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_3004018 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_3007529 is a subclass of http://purl.obolibrary.org/obo/ARO_3000008
# http://purl.obolibrary.org/obo/ARO_0000014 is a subclass of http://purl.obolibrary.org/obo/ARO_3007382
# http://purl.obolibrary.org/obo/ARO_3000655 is a subclass of http://purl.obolibrary.org/obo/ARO_3007382
# http://purl.obolibrary.org/obo/ARO_3004015 is a subclass of http://purl.obolibrary.org/obo/ARO_3007382
# http://purl.obolibrary.org/obo/ARO_3007376 is a subclass of http://purl.obolibrary.org/obo/ARO_3007382
# http://purl.obolibrary.org/obo/ARO_0000018 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_0000041 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3000035 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3000119 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3000123 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3000130 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3000134 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3000135 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3000136 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3000490 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3000686 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3000693 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3000694 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3000695 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3003241 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3003898 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3003903 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3003904 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3003919 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3003951 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3004121 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3007086 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3007093 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3007197 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3007478 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3007658 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3007686 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3007748 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3007779 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3007783 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_3007785 is a subclass of http://purl.obolibrary.org/obo/ARO_3000053
# http://purl.obolibrary.org/obo/ARO_0000022 is a subclass of http://purl.obolibrary.org/obo/ARO_3000035
# http://purl.obolibrary.org/obo/ARO_0000068 is a subclass of http://purl.obolibrary.org/obo/ARO_3000035
# http://purl.obolibrary.org/obo/ARO_3000685 is a subclass of http://purl.obolibrary.org/obo/ARO_3000035
# http://purl.obolibrary.org/obo/ARO_3000687 is a subclass of http://purl.obolibrary.org/obo/ARO_3000035
# http://purl.obolibrary.org/obo/ARO_3000697 is a subclass of http://purl.obolibrary.org/obo/ARO_3000035
# http://purl.obolibrary.org/obo/ARO_3003822 is a subclass of http://purl.obolibrary.org/obo/ARO_3000035
# http://purl.obolibrary.org/obo/ARO_3004374 is a subclass of http://purl.obolibrary.org/obo/ARO_3000035
# http://purl.obolibrary.org/obo/ARO_3004567 is a subclass of http://purl.obolibrary.org/obo/ARO_3000035
# http://purl.obolibrary.org/obo/ARO_3007629 is a subclass of http://purl.obolibrary.org/obo/ARO_3000035
# http://purl.obolibrary.org/obo/ARO_3007758 is a subclass of http://purl.obolibrary.org/obo/ARO_3000035
# http://purl.obolibrary.org/obo/ARO_0000023 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_0000036 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_0000071 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_0000074 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3000659 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3000660 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3000661 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3000662 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3000663 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3000664 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3000665 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3000666 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3000762 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3003690 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3004010 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3004011 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3004012 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3004013 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3004130 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3004462 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3004499 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3004731 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3004732 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3004733 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3005120 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3007022 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3007024 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3007045 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3007046 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3007165 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3007521 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_3007611 is a subclass of http://purl.obolibrary.org/obo/ARO_0000001
# http://purl.obolibrary.org/obo/ARO_0000025 is a subclass of http://purl.obolibrary.org/obo/ARO_3007149
# http://purl.obolibrary.org/obo/ARO_3000758 is a subclass of http://purl.obolibrary.org/obo/ARO_3007149
# http://purl.obolibrary.org/obo/ARO_0000028 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_0000029 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_0000053 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3000022 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3000117 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3000120 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3000184 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3000189 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3000466 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3000488 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3000525 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3000690 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3000691 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3000692 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3000767 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3004120 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3004477 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3005070 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3005071 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_3007525 is a subclass of http://purl.obolibrary.org/obo/ARO_3000081
# http://purl.obolibrary.org/obo/ARO_0000030 is a subclass of http://purl.obolibrary.org/obo/ARO_0000042
# http://purl.obolibrary.org/obo/ARO_0000031 is a subclass of N8fb193db20eb4e95add8512a6f1f0565
# http://purl.obolibrary.org/obo/ARO_0000032 is a subclass of http://purl.obolibrary.org/obo/ARO_3000276
# http://purl.obolibrary.org/obo/ARO_0000044 is a subclass of http://purl.obolibrary.org/obo/ARO_3000276
# http://purl.obolibrary.org/obo/ARO_0000034 is a subclass of http://purl.obolibrary.org/obo/ARO_0000026
# http://purl.obolibrary.org/obo/ARO_0000050 is a subclass of http://purl.obolibrary.org/obo/ARO_0000026
# http://purl.obolibrary.org/obo/ARO_0000042 is a subclass of http://purl.obolibrary.org/obo/ARO_3000050
# http://purl.obolibrary.org/obo/ARO_0000051 is a subclass of http://purl.obolibrary.org/obo/ARO_3000050
# http://purl.obolibrary.org/obo/ARO_0000069 is a subclass of http://purl.obolibrary.org/obo/ARO_3000050
# http://purl.obolibrary.org/obo/ARO_3000152 is a subclass of http://purl.obolibrary.org/obo/ARO_3000050
# http://purl.obolibrary.org/obo/ARO_3000528 is a subclass of http://purl.obolibrary.org/obo/ARO_3000050
# http://purl.obolibrary.org/obo/ARO_3000667 is a subclass of http://purl.obolibrary.org/obo/ARO_3000050
# http://purl.obolibrary.org/obo/ARO_3000668 is a subclass of http://purl.obolibrary.org/obo/ARO_3000050
# http://purl.obolibrary.org/obo/ARO_3003936 is a subclass of http://purl.obolibrary.org/obo/ARO_3000050
# http://purl.obolibrary.org/obo/ARO_3003979 is a subclass of http://purl.obolibrary.org/obo/ARO_3000050
# http://purl.obolibrary.org/obo/ARO_3007025 is a subclass of http://purl.obolibrary.org/obo/ARO_3000050
# http://purl.obolibrary.org/obo/ARO_0000045 is a subclass of http://purl.obolibrary.org/obo/ARO_3005386
# http://purl.obolibrary.org/obo/ARO_3000870 is a subclass of http://purl.obolibrary.org/obo/ARO_3005386
# http://purl.obolibrary.org/obo/ARO_3003823 is a subclass of http://purl.obolibrary.org/obo/ARO_3005386
# http://purl.obolibrary.org/obo/ARO_3005174 is a subclass of http://purl.obolibrary.org/obo/ARO_3005386
# http://purl.obolibrary.org/obo/ARO_3007039 is a subclass of http://purl.obolibrary.org/obo/ARO_3005386
# http://purl.obolibrary.org/obo/ARO_3007532 is a subclass of http://purl.obolibrary.org/obo/ARO_3005386
# http://purl.obolibrary.org/obo/ARO_0000046 is a subclass of http://purl.obolibrary.org/obo/ARO_0000017
# http://purl.obolibrary.org/obo/ARO_0000066 is a subclass of http://purl.obolibrary.org/obo/ARO_0000017
# http://purl.obolibrary.org/obo/ARO_3001231 is a subclass of http://purl.obolibrary.org/obo/ARO_0000017
# http://purl.obolibrary.org/obo/ARO_3007169 is a subclass of http://purl.obolibrary.org/obo/ARO_0000017
# http://purl.obolibrary.org/obo/ARO_3007636 is a subclass of http://purl.obolibrary.org/obo/ARO_0000017
# http://purl.obolibrary.org/obo/ARO_0000047 is a subclass of http://purl.obolibrary.org/obo/ARO_3000080
# http://purl.obolibrary.org/obo/ARO_3007639 is a subclass of http://purl.obolibrary.org/obo/ARO_3000080
# http://purl.obolibrary.org/obo/ARO_0000055 is a subclass of http://purl.obolibrary.org/obo/ARO_3007150
# http://purl.obolibrary.org/obo/ARO_0000058 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_0000059 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_0000060 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_0000061 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_0000062 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_0000063 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3000641 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3000642 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3000643 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3000644 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3000645 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3000646 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3000647 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3000648 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3000649 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3000650 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3000651 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3000704 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3003927 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3003999 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3004000 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3004002 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3004003 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3004005 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3004006 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3004007 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3004008 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3004009 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3004016 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3004017 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3004129 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3004474 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3004726 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3004727 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3007458 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3007475 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_3007571 is a subclass of http://purl.obolibrary.org/obo/ARO_0000032
# http://purl.obolibrary.org/obo/ARO_0000067 is a subclass of http://purl.obolibrary.org/obo/ARO_0000022
# http://purl.obolibrary.org/obo/ARO_3000454 is a subclass of http://purl.obolibrary.org/obo/ARO_0000022
# http://purl.obolibrary.org/obo/ARO_3000622 is a subclass of http://purl.obolibrary.org/obo/ARO_0000022
# http://purl.obolibrary.org/obo/ARO_3000624 is a subclass of http://purl.obolibrary.org/obo/ARO_0000022
# http://purl.obolibrary.org/obo/ARO_3000625 is a subclass of http://purl.obolibrary.org/obo/ARO_0000022
# http://purl.obolibrary.org/obo/ARO_3000626 is a subclass of http://purl.obolibrary.org/obo/ARO_0000022
# http://purl.obolibrary.org/obo/ARO_3000627 is a subclass of http://purl.obolibrary.org/obo/ARO_0000022
# http://purl.obolibrary.org/obo/ARO_3000628 is a subclass of http://purl.obolibrary.org/obo/ARO_0000022
# http://purl.obolibrary.org/obo/ARO_0000070 is a subclass of http://purl.obolibrary.org/obo/ARO_0000020
# http://purl.obolibrary.org/obo/ARO_0000073 is a subclass of http://purl.obolibrary.org/obo/ARO_0000020
# http://purl.obolibrary.org/obo/ARO_3000170 is a subclass of http://purl.obolibrary.org/obo/ARO_0000020
# http://purl.obolibrary.org/obo/ARO_3000640 is a subclass of http://purl.obolibrary.org/obo/ARO_0000020
# http://purl.obolibrary.org/obo/ARO_3003708 is a subclass of http://purl.obolibrary.org/obo/ARO_0000020
# http://purl.obolibrary.org/obo/ARO_3004473 is a subclass of http://purl.obolibrary.org/obo/ARO_0000020
# http://purl.obolibrary.org/obo/ARO_3007083 is a subclass of http://purl.obolibrary.org/obo/ARO_0000020
# http://purl.obolibrary.org/obo/ARO_3007143 is a subclass of http://purl.obolibrary.org/obo/ARO_0000020
# http://purl.obolibrary.org/obo/ARO_0000072 is a subclass of http://purl.obolibrary.org/obo/ARO_3000079
# http://purl.obolibrary.org/obo/ARO_3003897 is a subclass of http://purl.obolibrary.org/obo/ARO_3000079
# http://purl.obolibrary.org/obo/ARO_3007474 is a subclass of http://purl.obolibrary.org/obo/ARO_3000079
# http://purl.obolibrary.org/obo/ARO_3007480 is a subclass of http://purl.obolibrary.org/obo/ARO_3000079
# http://purl.obolibrary.org/obo/ARO_0000075 is a subclass of http://purl.obolibrary.org/obo/ARO_3004116
# http://purl.obolibrary.org/obo/ARO_3000688 is a subclass of http://purl.obolibrary.org/obo/ARO_3004116
# http://purl.obolibrary.org/obo/ARO_3007655 is a subclass of http://purl.obolibrary.org/obo/ARO_3004116
# http://purl.obolibrary.org/obo/ARO_3007677 is a subclass of http://purl.obolibrary.org/obo/ARO_3004116
# http://purl.obolibrary.org/obo/ARO_3007685 is a subclass of http://purl.obolibrary.org/obo/ARO_3004116
# http://purl.obolibrary.org/obo/ARO_0000076 is a subclass of http://purl.obolibrary.org/obo/ARO_1000001
# http://purl.obolibrary.org/obo/ARO_1000002 is a subclass of http://purl.obolibrary.org/obo/ARO_1000001
# http://purl.obolibrary.org/obo/ARO_1000003 is a subclass of http://purl.obolibrary.org/obo/ARO_1000001
# http://purl.obolibrary.org/obo/ARO_3000000 is a subclass of http://purl.obolibrary.org/obo/ARO_1000001
# http://purl.obolibrary.org/obo/ARO_3000045 is a subclass of http://purl.obolibrary.org/obo/ARO_1000001
# http://purl.obolibrary.org/obo/ARO_3000082 is a subclass of http://purl.obolibrary.org/obo/ARO_1000001
# http://purl.obolibrary.org/obo/ARO_3000708 is a subclass of http://purl.obolibrary.org/obo/ARO_1000001
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of http://purl.obolibrary.org/obo/ARO_3007130
# http://purl.obolibrary.org/obo/ARO_0000079 is a subclass of http://purl.obolibrary.org/obo/ARO_3007130
# http://purl.obolibrary.org/obo/ARO_3000587 is a subclass of http://purl.obolibrary.org/obo/ARO_3007130
# http://purl.obolibrary.org/obo/ARO_3004852 is a subclass of http://purl.obolibrary.org/obo/ARO_3007130
# http://purl.obolibrary.org/obo/ARO_3007141 is a subclass of http://purl.obolibrary.org/obo/ARO_3007130
# http://purl.obolibrary.org/obo/ARO_3007171 is a subclass of http://purl.obolibrary.org/obo/ARO_3007130
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of Nffb2280aac9149868d901ef6fd677fc5
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of Naeb4f3698fff490d9dcbcf645b1f65a5
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of Nd4af1ab10a784402863c2d69ac0c06c5
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of Nf58d949258e44228ad7d7647fb5f31e6
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of N54328933f14e46d0b090c0ff78d861f4
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of Nf47a54db77a24e68a91e36e73b93d5e5
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of N6d7694b9115e4e30a5f9b2b73a589bd0
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of N55cdd9170b744f9e8c8c8e3bbc802abe
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of N6179c8e9e8db431c8df533fc7f5cbc8b
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of N1675cbefb1724d3aaeb1a9f0f6686953
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of N038736d25ed1486b83653d1eabb7fe63
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of N731c77c9decd454ab16d6c38a7b0700e
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of N55a7505a01814648a1c912633aebfbf1
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of Naa96b51a4b744554ad574a83872b8725
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of N2178a761858341a583339760327952b6
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of N00f5909139234530b95f0521c322c814
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of Na0c0419ffbbd4935a5b663f39fc4f158
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of N74303d70aeea43da85bc6edd976588bf
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of N790ba7ce380f48b6abb3732bc5dfe7f7
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of N581adfc9191a4087a0a939ebe63bd77d
# http://purl.obolibrary.org/obo/ARO_0000077 is a subclass of N420f29fe2efe40f987ca2c4780280506
# http://purl.obolibrary.org/obo/ARO_0000079 is a subclass of N95c8213941514eaabd8634442266e18d
# http://purl.obolibrary.org/obo/ARO_0000079 is a subclass of N9734d65ef851438da552425309898eba
# http://purl.obolibrary.org/obo/ARO_0000079 is a subclass of N934e74647d124225b02b99ca35bcd1c9
# http://purl.obolibrary.org/obo/ARO_0000079 is a subclass of N2056c2d5c4dd456e8b13bcbac4db83e8
# http://purl.obolibrary.org/obo/ARO_0000079 is a subclass of Nf337c4db7cb64e20a10babd2e28ca976
# http://purl.obolibrary.org/obo/ARO_0000079 is a subclass of N9d15f0fe075e4434ad2ed8fcffac1034
# http://purl.obolibrary.org/obo/ARO_0000079 is a subclass of Nb356b154bc984554a4dd1bb5c1ed89e4
# ...
# http://purl.obolibrary.org/obo/ARO_3007666 is a subclass of http://purl.obolibrary.org/obo/ARO_3007667
# http://purl.obolibrary.org/obo/ARO_3007666 is a subclass of Nb2c1896d2bae4c2ca468c9464c71fbae
# http://purl.obolibrary.org/obo/ARO_3007666 is a subclass of Nad4849aec4ff403cb555535ef2101f15
# http://purl.obolibrary.org/obo/ARO_3007666 is a subclass of N6fd406d997244464b21459f05c077085
# http://purl.obolibrary.org/obo/ARO_3007667 is a subclass of Nf1440d55f3b045019c55baa262676ef1
# http://purl.obolibrary.org/obo/ARO_3007668 is a subclass of Ncb1a340c643540d4b8930811956b7e2e
# http://purl.obolibrary.org/obo/ARO_3007669 is a subclass of Nacb2beb5f5ac48ecaa3593549f25047d
# http://purl.obolibrary.org/obo/ARO_3007669 is a subclass of N8a2e948b572f48ee8a1d11e496c9b8fe
# http://purl.obolibrary.org/obo/ARO_3007669 is a subclass of Ne666a19f34204666800577d15b62898f
# http://purl.obolibrary.org/obo/ARO_3007670 is a subclass of http://purl.obolibrary.org/obo/ARO_3007668
# http://purl.obolibrary.org/obo/ARO_3007670 is a subclass of N930bde6dd45746f49e7873664b94b30b
# http://purl.obolibrary.org/obo/ARO_3007670 is a subclass of N190fc94cb1dd462abab0c5a177cc81d8
# http://purl.obolibrary.org/obo/ARO_3007670 is a subclass of N492d0073bb594de6aed9b6360f8f41c1
# http://purl.obolibrary.org/obo/ARO_3007670 is a subclass of N5ffaca782dc348d8b457081f59f5dff5
# http://purl.obolibrary.org/obo/ARO_3007671 is a subclass of N5d3ac3a37b2b4e17846e72e431746a25
# http://purl.obolibrary.org/obo/ARO_3007673 is a subclass of http://purl.obolibrary.org/obo/ARO_3007672
# http://purl.obolibrary.org/obo/ARO_3007673 is a subclass of N7ab108b7dd844091bd0a4aa6ea36dc12
# http://purl.obolibrary.org/obo/ARO_3007673 is a subclass of N057c63ac85f14dd48619bee405bc21bb
# http://purl.obolibrary.org/obo/ARO_3007674 is a subclass of http://purl.obolibrary.org/obo/ARO_3007673
# http://purl.obolibrary.org/obo/ARO_3007674 is a subclass of N7f4f4cfb28cf42219189eedb882db4a9
# http://purl.obolibrary.org/obo/ARO_3007678 is a subclass of http://purl.obolibrary.org/obo/ARO_3007683
# http://purl.obolibrary.org/obo/ARO_3007678 is a subclass of N9ad6b98a7abf4f9196f4d67a1e36722b
# http://purl.obolibrary.org/obo/ARO_3007683 is a subclass of N9291247124f945fb94cfa9c3e9da2965
# http://purl.obolibrary.org/obo/ARO_3007684 is a subclass of Ncbce6b18dfd04d46ae069d1868fedbb8
# http://purl.obolibrary.org/obo/ARO_3007691 is a subclass of http://purl.obolibrary.org/obo/ARO_3007690
# http://purl.obolibrary.org/obo/ARO_3007691 is a subclass of N34c81ddce576494ab2f529f7e81e6a15
# http://purl.obolibrary.org/obo/ARO_3007692 is a subclass of http://purl.obolibrary.org/obo/ARO_3007691
# http://purl.obolibrary.org/obo/ARO_3007692 is a subclass of Need5976610374976b40578efc925971a
# http://purl.obolibrary.org/obo/ARO_3007692 is a subclass of N888c8fae73d84b1b86efeb7b975ec535
# http://purl.obolibrary.org/obo/ARO_3007693 is a subclass of N477543eb5f63435babc6f16fd9aa167e
# http://purl.obolibrary.org/obo/ARO_3007693 is a subclass of N5973d7d67dc74b40bdb28701704e5793
# http://purl.obolibrary.org/obo/ARO_3007694 is a subclass of http://purl.obolibrary.org/obo/ARO_3007693
# http://purl.obolibrary.org/obo/ARO_3007694 is a subclass of N78c3b63546514a35b51b34e000a3bc8b
# http://purl.obolibrary.org/obo/ARO_3007694 is a subclass of N6de7cb616bf841e297cb2e6207c4831d
# http://purl.obolibrary.org/obo/ARO_3007694 is a subclass of N41a2ba8333094bc68676b236fe0e475d
# http://purl.obolibrary.org/obo/ARO_3007694 is a subclass of N04ba0e1284db4fe78929d4f3b99722d3
# http://purl.obolibrary.org/obo/ARO_3007694 is a subclass of N531304c2e5a940c5aa7fea64d61f459f
# http://purl.obolibrary.org/obo/ARO_3007696 is a subclass of N6efa765adbb24018a59bd10af479460b
# http://purl.obolibrary.org/obo/ARO_3007696 is a subclass of Nc51a66a1a1e84bfb86a253e435de8752
# http://purl.obolibrary.org/obo/ARO_3007697 is a subclass of N353ef6bdc6664a40a83e024b8e55e7f6
# http://purl.obolibrary.org/obo/ARO_3007697 is a subclass of Nef07b755f7244f37b1e990f4fb638aff
# http://purl.obolibrary.org/obo/ARO_3007698 is a subclass of N5274a978f59a4c1cbe08335f46802ac7
# http://purl.obolibrary.org/obo/ARO_3007699 is a subclass of N7146796721884e0681dd7aba550ad0dc
# http://purl.obolibrary.org/obo/ARO_3007700 is a subclass of N8a8e9e044be24d9dabc8431bc953b4fe
# http://purl.obolibrary.org/obo/ARO_3007700 is a subclass of N58c605da32b6435d885ce1f90f8463a3
# http://purl.obolibrary.org/obo/ARO_3007701 is a subclass of N2716fe50288142059661bc3f627c43c4
# http://purl.obolibrary.org/obo/ARO_3007701 is a subclass of N4c66e60f57584c8186a6adfcd4fca8d2
# http://purl.obolibrary.org/obo/ARO_3007702 is a subclass of N6eaec341c0a74c19926dea36a1e451b5
# http://purl.obolibrary.org/obo/ARO_3007703 is a subclass of N87a903d45bdc483aa16c10f486cbee64
# http://purl.obolibrary.org/obo/ARO_3007703 is a subclass of N6f663f0f9729467dbc537ddf84fad2a9
# http://purl.obolibrary.org/obo/ARO_3007704 is a subclass of N940c38584dfb4b6f811eda221efb9509
# http://purl.obolibrary.org/obo/ARO_3007704 is a subclass of N61dd7d83cc1a462d9ae250c22ab71279
# http://purl.obolibrary.org/obo/ARO_3007705 is a subclass of N09e59be7bddd43029dbba3b21b0ed6ab
# http://purl.obolibrary.org/obo/ARO_3007705 is a subclass of N99d3b9c9f0104f9d8120dd30e2ad3a07
# http://purl.obolibrary.org/obo/ARO_3007706 is a subclass of N7d02a051b3274896aff2a02c58ff70a8
# http://purl.obolibrary.org/obo/ARO_3007706 is a subclass of N109e3ba1dbe2433cb3b84a930aab7462
# http://purl.obolibrary.org/obo/ARO_3007707 is a subclass of N1a31b663ecb8456caba983b4a81712f7
# http://purl.obolibrary.org/obo/ARO_3007707 is a subclass of N8b2697f8594f48f4b465a3fb088ad82e
# http://purl.obolibrary.org/obo/ARO_3007708 is a subclass of N6fa82eb03bba4fc9b811bc2b8aa3f452
# http://purl.obolibrary.org/obo/ARO_3007708 is a subclass of N25ef39afc58a47daaac1c5629e24ec83
# http://purl.obolibrary.org/obo/ARO_3007709 is a subclass of N2b3d26e6edeb45fa929a4a8391b3b1d6
# http://purl.obolibrary.org/obo/ARO_3007709 is a subclass of Naa630ac5473f4dbbb77753ddbfa021d3
# http://purl.obolibrary.org/obo/ARO_3007710 is a subclass of Nc6d0405aa35a49ef8a5996925015e0cd
# http://purl.obolibrary.org/obo/ARO_3007710 is a subclass of N4f06d5bd81394e3c99efcecbe6b2cecd
# http://purl.obolibrary.org/obo/ARO_3007711 is a subclass of N17a0476a65c5493a8f137e06d7a2d47a
# http://purl.obolibrary.org/obo/ARO_3007711 is a subclass of Ndcd9c71d1ad74f53b4f1ad9c8a7667ce
# http://purl.obolibrary.org/obo/ARO_3007712 is a subclass of N40dc20738c784eb28817be49bbd43b30
# http://purl.obolibrary.org/obo/ARO_3007713 is a subclass of N880bc490b0974c88962728836d587f19
# http://purl.obolibrary.org/obo/ARO_3007713 is a subclass of N6b46be1b14724375bd81043903c0a4f4
# http://purl.obolibrary.org/obo/ARO_3007714 is a subclass of N80f0d282e9714b23ade28eab38aae1d4
# http://purl.obolibrary.org/obo/ARO_3007714 is a subclass of Nc070933915ff42cdbd49c90a53ad0569
# http://purl.obolibrary.org/obo/ARO_3007715 is a subclass of Nb09e14d2a54042c285d8a9ce8367459c
# http://purl.obolibrary.org/obo/ARO_3007716 is a subclass of Ndaac5a81216d4e959a22ab3a1844d779
# http://purl.obolibrary.org/obo/ARO_3007717 is a subclass of N31b80804db3640a5b1c9aafdfe6a5758
# http://purl.obolibrary.org/obo/ARO_3007717 is a subclass of N76fb2d8678df4b0f808ded7113dfeda9
# http://purl.obolibrary.org/obo/ARO_3007718 is a subclass of N95b3b09a61a74c7198f6ba5152b4c8ff
# http://purl.obolibrary.org/obo/ARO_3007719 is a subclass of N2db340ddbe794735a95f38b977dd3e7c
# http://purl.obolibrary.org/obo/ARO_3007719 is a subclass of Na4cbdd43e4374aa19260b11f03a065b0
# http://purl.obolibrary.org/obo/ARO_3007720 is a subclass of N589294a573d1428f92e0b40a5df950a6
# http://purl.obolibrary.org/obo/ARO_3007721 is a subclass of N2e53230de9554980a25de64ff08a83bd
# http://purl.obolibrary.org/obo/ARO_3007721 is a subclass of Nddf42d4dae7e4a49bca719040706034c
# http://purl.obolibrary.org/obo/ARO_3007722 is a subclass of N1878a75d8a2f4a1db34ad0501275faa5
# http://purl.obolibrary.org/obo/ARO_3007723 is a subclass of N4ea89c86b67d4c429d409ff073d01654
# http://purl.obolibrary.org/obo/ARO_3007724 is a subclass of N2f2b184d98e2437c8849a3b27485ed3b
# http://purl.obolibrary.org/obo/ARO_3007725 is a subclass of N0d1312780fec4580a4fb4fae6d7fa607
# http://purl.obolibrary.org/obo/ARO_3007725 is a subclass of Nc6fb4c9304454c17a7a2162874f46f2c
# http://purl.obolibrary.org/obo/ARO_3007726 is a subclass of Nf3b45f16a4bc4be598bbfd719a912822
# http://purl.obolibrary.org/obo/ARO_3007727 is a subclass of Nb46e7fc5949b47698bb41f3c01b0df82
# http://purl.obolibrary.org/obo/ARO_3007727 is a subclass of Nd2aec49f679a43c3bb05ec0936b6598d
# http://purl.obolibrary.org/obo/ARO_3007728 is a subclass of Nde1e62342fe04a2c9eb6936858effa49
# http://purl.obolibrary.org/obo/ARO_3007728 is a subclass of N8a2d382c42f44f569cb36d0fdf0e869e
# http://purl.obolibrary.org/obo/ARO_3007729 is a subclass of N46368b7238db41dd9876967de6d1eaa8
# http://purl.obolibrary.org/obo/ARO_3007729 is a subclass of N1b96d7c65d414bcabd0e68a84ce44101
# http://purl.obolibrary.org/obo/ARO_3007730 is a subclass of Nf0fc3cc416244d329e5af1f051316d0b
# http://purl.obolibrary.org/obo/ARO_3007731 is a subclass of N19736f044a1946d9a73e603b4fc10a43
# http://purl.obolibrary.org/obo/ARO_3007731 is a subclass of N91bd1a29872a41d5b528d49773e5e87f
# http://purl.obolibrary.org/obo/ARO_3007732 is a subclass of N1f768515597b4f338810b97e28a79a19
# http://purl.obolibrary.org/obo/ARO_3007733 is a subclass of N7ff994cd6be54fdfb46d624c09136040
# http://purl.obolibrary.org/obo/ARO_3007733 is a subclass of N1b9d8a211e724eb39f9f599c6b16153d
# http://purl.obolibrary.org/obo/ARO_3007734 is a subclass of Ne77156ab30d1413ba9169c61791a0bf0
# http://purl.obolibrary.org/obo/ARO_3007735 is a subclass of Nd4d53dde0203451e994a375d4acf6f96
# http://purl.obolibrary.org/obo/ARO_3007749 is a subclass of N0f3dc0298685490e95fa038112802737
# http://purl.obolibrary.org/obo/ARO_3007751 is a subclass of Nf4eaca4efb42404ea34b73f6f4dd12ee
# http://purl.obolibrary.org/obo/ARO_3007751 is a subclass of N73da9545f2b5428f8c929d69abfd9dd7
# http://purl.obolibrary.org/obo/ARO_3007752 is a subclass of N99d13193f97941729e062be57125cfd9
# http://purl.obolibrary.org/obo/ARO_3007752 is a subclass of N6a82b4dea3ae4b2bb71f96e638e4fe15
# http://purl.obolibrary.org/obo/ARO_3007759 is a subclass of Na2339a2f4e154fc587eb7610f416e757
# http://purl.obolibrary.org/obo/ARO_3007764 is a subclass of http://purl.obolibrary.org/obo/ARO_3007763
# http://purl.obolibrary.org/obo/ARO_3007765 is a subclass of http://purl.obolibrary.org/obo/ARO_3007763
# http://purl.obolibrary.org/obo/ARO_3007766 is a subclass of http://purl.obolibrary.org/obo/ARO_3007763
# http://purl.obolibrary.org/obo/ARO_3007767 is a subclass of http://purl.obolibrary.org/obo/ARO_3007763
# http://purl.obolibrary.org/obo/ARO_3007770 is a subclass of Naffdc1c0e7164ac29f0d6e7c3bfa7ab2
# http://purl.obolibrary.org/obo/ARO_3007770 is a subclass of N86d9bed239a1480cb3f68db2aa25c5dd
# http://purl.obolibrary.org/obo/ARO_3007770 is a subclass of Ne1aecde142e14a94beade04beee38388
# http://purl.obolibrary.org/obo/ARO_3007770 is a subclass of N8cb0e53e47bf4fc28841c1526a009c7c
# http://purl.obolibrary.org/obo/ARO_3007771 is a subclass of Nee81ae27c7174f249bcbfc07680265b3
# http://purl.obolibrary.org/obo/ARO_3007771 is a subclass of N366c6083ef42450eab305ad2d87139a7
# http://purl.obolibrary.org/obo/ARO_3007771 is a subclass of N3b59d50f96ab48659dd1c48e5dbc03e4
# http://purl.obolibrary.org/obo/ARO_3007771 is a subclass of N1ad899116a734a999827b6100444a1e1
# http://purl.obolibrary.org/obo/ARO_3007774 is a subclass of http://purl.obolibrary.org/obo/ARO_3007773
# http://purl.obolibrary.org/obo/ARO_3007775 is a subclass of http://purl.obolibrary.org/obo/ARO_3007773
# http://purl.obolibrary.org/obo/ARO_3007776 is a subclass of http://purl.obolibrary.org/obo/ARO_3007773
# http://purl.obolibrary.org/obo/ARO_3007777 is a subclass of http://purl.obolibrary.org/obo/ARO_3007773
# http://purl.obolibrary.org/obo/ARO_3007778 is a subclass of http://purl.obolibrary.org/obo/ARO_3007773
# http://purl.obolibrary.org/obo/ARO_3007780 is a subclass of http://purl.obolibrary.org/obo/ARO_3007779
# http://purl.obolibrary.org/obo/ARO_3007781 is a subclass of http://purl.obolibrary.org/obo/ARO_3007779
# http://purl.obolibrary.org/obo/ARO_3007782 is a subclass of http://purl.obolibrary.org/obo/ARO_3007779
# http://purl.obolibrary.org/obo/ARO_3007784 is a subclass of http://purl.obolibrary.org/obo/ARO_3007783
# http://purl.obolibrary.org/obo/ARO_3007787 is a subclass of http://purl.obolibrary.org/obo/ARO_3007786
# http://purl.obolibrary.org/obo/ARO_3007788 is a subclass of http://purl.obolibrary.org/obo/ARO_3007786
# http://purl.obolibrary.org/obo/ARO_3007789 is a subclass of http://purl.obolibrary.org/obo/ARO_3007786
# http://purl.obolibrary.org/obo/ARO_3007790 is a subclass of http://purl.obolibrary.org/obo/ARO_3007786
# http://purl.obolibrary.org/obo/ARO_3007791 is a subclass of http://purl.obolibrary.org/obo/ARO_3007786
# http://purl.obolibrary.org/obo/ARO_3007794 is a subclass of N6b24a5764c99454083c013d588d5bca5
# http://purl.obolibrary.org/obo/ARO_3007797 is a subclass of N6c6fbd6898d346febdfdf5e82a3e154c
# http://purl.obolibrary.org/obo/ARO_3007798 is a subclass of http://purl.obolibrary.org/obo/ARO_3007799
# http://purl.obolibrary.org/obo/ARO_3007798 is a subclass of Nfa04237d0c1d49fb91d77034d6bb3924
# http://purl.obolibrary.org/obo/ARO_3007800 is a subclass of Na64eebf467ef4687b90bc1aaec587e3c
# http://purl.obolibrary.org/obo/ARO_3007801 is a subclass of http://purl.obolibrary.org/obo/ARO_3007800
# http://purl.obolibrary.org/obo/ARO_3007802 is a subclass of http://purl.obolibrary.org/obo/ARO_3007800
# http://purl.obolibrary.org/obo/ARO_3007805 is a subclass of Nd3a22c8ed70141eeb7ae1edc3a921fb3
# http://purl.obolibrary.org/obo/ARO_3007806 is a subclass of N4bf203f147e146bf99b0ce92b30cbf31
# http://purl.obolibrary.org/obo/ARO_3007807 is a subclass of Nd4e91d30b8e040d8812b7dee7c8479c1
# http://purl.obolibrary.org/obo/ARO_3007808 is a subclass of Nd57dd50daed44610b82ea62060b11e77
# http://purl.obolibrary.org/obo/ARO_3007809 is a subclass of N90e6818bcff94dd6b5660cc7a368220d
# http://purl.obolibrary.org/obo/ARO_3007810 is a subclass of Ncfceed5d524d4aa69db047bc69337ca8
# http://purl.obolibrary.org/obo/ARO_3007811 is a subclass of http://purl.obolibrary.org/obo/ARO_3007841
# http://purl.obolibrary.org/obo/ARO_3007811 is a subclass of Nad318d7e1da74a709b274eda680ce223
# http://purl.obolibrary.org/obo/ARO_3007838 is a subclass of N28a5c10c2c8747cc842ff4bd3f061dfd
# http://purl.obolibrary.org/obo/ARO_3007839 is a subclass of Nec25b084f3c54893bfe33378a112988e
# http://purl.obolibrary.org/obo/ARO_3007839 is a subclass of Nd9f186f816b54d04a89d22ed4ec65996
# http://purl.obolibrary.org/obo/ARO_3007840 is a subclass of http://purl.obolibrary.org/obo/ARO_3007839
# http://purl.obolibrary.org/obo/ARO_3007841 is a subclass of Ne7b59a70a8174360ad0c6f8d44a97e81
# http://purl.obolibrary.org/obo/DOID_0050161 is a subclass of http://purl.obolibrary.org/obo/DOID_1579
# http://purl.obolibrary.org/obo/DOID_11162 is a subclass of http://purl.obolibrary.org/obo/DOID_850
# http://purl.obolibrary.org/obo/DOID_11394 is a subclass of http://purl.obolibrary.org/obo/DOID_11162
# http://purl.obolibrary.org/obo/DOID_12716 is a subclass of http://purl.obolibrary.org/obo/DOID_11162
# http://purl.obolibrary.org/obo/DOID_13148 is a subclass of http://purl.obolibrary.org/obo/ARO_3004430
# http://purl.obolibrary.org/obo/DOID_1579 is a subclass of http://purl.obolibrary.org/obo/ARO_3004430
# http://purl.obolibrary.org/obo/DOID_37 is a subclass of http://purl.obolibrary.org/obo/ARO_3004430
# http://purl.obolibrary.org/obo/HP_0031292 is a subclass of http://purl.obolibrary.org/obo/ARO_3004430
# http://purl.obolibrary.org/obo/SYMP_0000092 is a subclass of http://purl.obolibrary.org/obo/ARO_3004430
# http://purl.obolibrary.org/obo/UBERON_0001003 is a subclass of http://purl.obolibrary.org/obo/ARO_3004430
# http://purl.obolibrary.org/obo/UBERON_0003134 is a subclass of http://purl.obolibrary.org/obo/ARO_3004430
# http://purl.obolibrary.org/obo/UBERON_0003135 is a subclass of http://purl.obolibrary.org/obo/ARO_3004430
# http://purl.obolibrary.org/obo/DOID_850 is a subclass of http://purl.obolibrary.org/obo/DOID_0050161

# %%
from rdflib import Graph, Namespace, RDF, RDFS, OWL
from neo4j import GraphDatabase

# Function to import OWL data into Neo4j
def import_owl_to_neo4j(owl_file, neo4j_uri, neo4j_user, neo4j_password):
    # Load the OWL file
    g = Graph()
    g.parse(owl_file)

    # Define the namespaces
    OWL_NS = Namespace("http://www.w3.org/2002/07/owl#")
    RDF_NS = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
    RDFS_NS = Namespace("http://www.w3.org/2000/01/rdf-schema#")
    
    # Connect to Neo4j
    driver = GraphDatabase.driver(neo4j_uri, auth=(neo4j_user, neo4j_password))
    
    with driver.session() as session:
        # Iterate over the classes in the OWL file
        for s, p, o in g.triples((None, RDF.type, OWL.Class)):
            class_name = str(s)
            session.run("CREATE (c:Class {name: $name})", name=class_name)
        
        # Iterate over the properties in the OWL file
        for s, p, o in g.triples((None, RDF.type, OWL.ObjectProperty)):
            property_name = str(s)
            session.run("CREATE (p:ObjectProperty {name: $name})", name=property_name)

        # Iterate over the instances in the OWL file
        for s, p, o in g.triples((None, RDF.type, OWL.NamedIndividual)):
            individual_name = str(s)
            session.run("CREATE (i:Individual {name: $name})", name=individual_name)

        # Create relationships (subclasses, properties)
        for s, p, o in g.triples((None, RDFS.subClassOf, None)):
            subclass = str(s)
            superclass = str(o)
            session.run("""
                MATCH (sub:Class {name: $subclass}), (super:Class {name: $superclass})
                CREATE (sub)-[:SUBCLASS_OF]->(super)
            """, subclass=subclass, superclass=superclass)

        for s, p, o in g.triples((None, RDFS.domain, None)):
            property_name = str(s)
            domain_class = str(o)
            session.run("""
                MATCH (p:ObjectProperty {name: $property_name}), (c:Class {name: $domain_class})
                CREATE (p)-[:HAS_DOMAIN]->(c)
            """, property_name=property_name, domain_class=domain_class)

        for s, p, o in g.triples((None, RDFS.range, None)):
            property_name = str(s)
            range_class = str(o)
            session.run("""
                MATCH (p:ObjectProperty {name: $property_name}), (c:Class {name: $range_class})
                CREATE (p)-[:HAS_RANGE]->(c)
            """, property_name=property_name, range_class=range_class)

    driver.close()
    print("Ontology imported successfully!")

# Example usage
import_owl_to_neo4j(
    owl_file="path/to/your/ontology.owl",
    neo4j_uri="bolt://localhost:7687",
    neo4j_user="neo4j",
    neo4j_password="your_password"
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 63
#      60     print("Ontology imported successfully!")
#      62 # Example usage
# ---> 63 import_owl_to_neo4j(
#      64     owl_file="path/to/your/ontology.owl",
#      65     neo4j_uri="bolt://localhost:7687",
#      66     neo4j_user="neo4j",
#      67     neo4j_password="your_password"
#      68 )
#
# Cell In[4], line 8, in import_owl_to_neo4j(owl_file, neo4j_uri, neo4j_user, neo4j_password)
#       5 def import_owl_to_neo4j(owl_file, neo4j_uri, neo4j_user, neo4j_password):
#       6     # Load the OWL file
#       7     g = Graph()
# ----> 8     g.parse(owl_file)
#      10     # Define the namespaces
#      11     OWL_NS = Namespace("http://www.w3.org/2002/07/owl#")
#
# File ~/anaconda3/envs/pyeed_niklas/lib/python3.12/site-packages/rdflib/graph.py:1467, in Graph.parse(self, source, publicID, format, location, file, data, **args)
#    1372 def parse(
#    1373     self,
#    1374     source: Optional[
#    (...)
#    1382     **args: Any,
#    1383 ) -> Graph:
#    1384     """
#    1385     Parse an RDF source adding the resulting triples to the Graph.
#    1386
#    (...)
#    1464
#    1465     """
# -> 1467     source = create_input_source(
#    1468         source=source,
#    1469         publicID=publicID,
#    1470         location=location,
#    1471         file=file,
#    1472         data=data,
#    1473         format=format,
#    1474     )
#    1475     if format is None:
#    1476         format = source.content_type
#
# File ~/anaconda3/envs/pyeed_niklas/lib/python3.12/site-packages/rdflib/parser.py:735, in create_input_source(source, publicID, location, file, data, format)
#     728         assert data is None
#     729         assert source is None
#     730     (
#     731         absolute_location,
#     732         auto_close,
#     733         file,
#     734         input_source,
# --> 735     ) = _create_input_source_from_location(
#     736         file=file,
#     737         format=format,
#     738         input_source=input_source,
#     739         location=location,
#     740     )
#     742 if file is not None:
#     743     if TYPE_CHECKING:
#
# File ~/anaconda3/envs/pyeed_niklas/lib/python3.12/site-packages/rdflib/parser.py:795, in _create_input_source_from_location(file, format, input_source, location)
#     793 if absolute_location.startswith("file:///"):
#     794     filename = url2pathname(absolute_location.replace("file:///", "/"))
# --> 795     file = open(filename, "rb")
#     796 else:
#     797     input_source = URLInputSource(absolute_location, format)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nab/Niklas/path/to/your/ontology.owl'

# %%
print(onto.search(is_a = onto.ARO_0000005))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(onto.search(is_a = onto.ARO_0000005))
#
# File ~/anaconda3/envs/pyeed_niklas/lib/python3.12/site-packages/owlready2/namespace.py:298, in _GraphManager.search(self, _use_str_as_loc_str, _case_sensitive, _bm25, **kargs)
#     296   if   isinstance(v, (_SearchMixin, Or)): v2 = v
#     297   elif isinstance(v, int):                v2 = v
# --> 298   else:                                   v2 = v.storid
#     299   prop_vals.append((" %s" % k, v2, None))
#     300 else:
#
# AttributeError: 'NoneType' object has no attribute 'storid'

# %%
for owl_class in onto.classes():
    print(f"Class: {owl_class.name}")
    
    # Get attributes and relationships at the class level
    data_properties, object_properties = get_properties(owl_class)

    # Display class-level attributes and relationships
    if data_properties:
        print(f"  Data Properties (attributes): {', '.join(data_properties)}")
    else:
        print("  Data Properties (attributes): None")
    
    if object_properties:
        print(f"  Object Properties (relationships): {', '.join(object_properties)}")
    else:
        print("  Object Properties (relationships): None")

    # Display instance-level attributes if available
    instances = list(owl_class.instances())
    if instances:
        print(f"  Instances of {owl_class.name}:")
        for instance in instances:
            print(f"    Instance: {instance.name}")
            instance_data_props, instance_obj_props = get_properties(instance)

            if instance_data_props:
                print(f"      Data Properties (attributes): {', '.join(instance_data_props)}")
            else:
                print("      Data Properties (attributes): None")

            if instance_obj_props:
                print(f"      Object Properties (relationships): {', '.join(instance_obj_props)}")
            else:
                print("      Object Properties (relationships): None")

    print("-" * 50)
# Out:
# Class: ARO_0000000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       2 print(f"Class: {owl_class.name}")
#       4 # Get attributes and relationships at the class level
# ----> 5 data_properties, object_properties = get_properties(owl_class)
#       7 # Display class-level attributes and relationships
#       8 if data_properties:
#
# NameError: name 'get_properties' is not defined

# %%
def print_class_hierarchy(onto_class, level=0):
    # Print the current class
    print("  " * level + onto_class.name)

    # Recurse for each subclass
    for subclass in onto_class.subclasses():
        print_class_hierarchy(subclass, level + 1)

# Print the hierarchy starting from the root class
print("Class hierarchy in the ontology:")
for root_class in onto.classes():
    # Only show the top-level classes (those with no parent in the ontology)
    if not list(root_class.is_a):
        print_class_hierarchy(root_class)
# Out:
# Class hierarchy in the ontology:

# %%
from IPython.display import Image

# Render without viewing and display in Jupyter
onto.graph.render(filename="ontology_graph", format="png", view=False)
Image(filename="ontology_graph.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 4
#       1 from IPython.display import Image
#       3 # Render without viewing and display in Jupyter
# ----> 4 onto.graph.render(filename="ontology_graph", format="png", view=False)
#       5 Image(filename="ontology_graph.png")
#
# AttributeError: 'SubGraph' object has no attribute 'render'

# %%
onto.save(file="ontology_graph.dot", format="rdfxml")  # "rdfxml" here is used to export the file format.

# %%
import pydot
from IPython.display import Image

# Load the DOT file and convert it to PNG format
(graph,) = pydot.graph_from_dot_file("ontology_graph.dot")
graph.write_png("ontology_graph.png")

# Display the image in Jupyter Notebook
Image(filename="ontology_graph.png")
# Out:
# <?xml version="1.0"?>
# ^
# Expected {'GRAPH' | 'DIGRAPH'}, found '<'  (at char 0), (line:1, col:1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 from IPython.display import Image
#       4 # Load the DOT file and convert it to PNG format
# ----> 5 (graph,) = pydot.graph_from_dot_file("ontology_graph.dot")
#       6 graph.write_png("ontology_graph.png")
#       8 # Display the image in Jupyter Notebook
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
import rdflib
import networkx as nx
import matplotlib.pyplot as plt
from networkx.drawing.nx_agraph import graphviz_layout

# Load and parse the ontology
ontology_file = "/home/nab/Niklas/TEM-lactamase/CARD_Data_Ontologies/aro.owl"  # Replace with the path to your ontology file
g = rdflib.Graph()
g.parse(ontology_file, format="xml")

# Initialize a directed graph in networkx
G = nx.DiGraph()

# Parse classes and relationships in the ontology
for s, p, o in g:
    # Add nodes and edges for ontology terms
    G.add_node(s, label=str(s).split("/")[-1])  # Use the fragment of the URI for labeling
    G.add_node(o, label=str(o).split("/")[-1])  # Target node as well
    G.add_edge(s, o, label=str(p).split("/")[-1])  # Add directed edge for relationships

# Plot the ontology structure
plt.figure(figsize=(12, 12))
pos = graphviz_layout(G, prog="dot")
edge_labels = nx.get_edge_attributes(G, "label")
nx.draw(G, pos, with_labels=True, labels=nx.get_node_attributes(G, "label"), node_size=3000, node_color="lightblue", font_size=10)
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color="red")

plt.title("Ontology Structure Visualization")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/anaconda3/envs/pyeed_niklas/lib/python3.12/site-packages/networkx/drawing/nx_agraph.py:302, in pygraphviz_layout(G, prog, root, args)
#     301 try:
# --> 302     import pygraphviz
#     303 except ImportError as err:
#
# ModuleNotFoundError: No module named 'pygraphviz'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 23
#      21 # Plot the ontology structure
#      22 plt.figure(figsize=(12, 12))
# ---> 23 pos = graphviz_layout(G, prog="dot")
#      24 edge_labels = nx.get_edge_attributes(G, "label")
#      25 nx.draw(G, pos, with_labels=True, labels=nx.get_node_attributes(G, "label"), node_size=3000, node_color="lightblue", font_size=10)
#
# File ~/anaconda3/envs/pyeed_niklas/lib/python3.12/site-packages/networkx/drawing/nx_agraph.py:258, in graphviz_layout(G, prog, root, args)
#     227 def graphviz_layout(G, prog="neato", root=None, args=""):
#     228     """Create node positions for G using Graphviz.
#     229
#     230     Parameters
#    (...)
#     256     see https://gitlab.com/graphviz/graphviz/-/issues/1767 for more info.
#     257     """
# --> 258     return pygraphviz_layout(G, prog=prog, root=root, args=args)
#
# File ~/anaconda3/envs/pyeed_niklas/lib/python3.12/site-packages/networkx/drawing/nx_agraph.py:304, in pygraphviz_layout(G, prog, root, args)
#     302     import pygraphviz
#     303 except ImportError as err:
# --> 304     raise ImportError("requires pygraphviz http://pygraphviz.github.io/") from err
#     305 if root is not None:
#     306     args += f"-Groot={root}"
#
# ImportError: requires pygraphviz http://pygraphviz.github.io/

# %%
from cgitb import text
from tkinter import font
from py2neo import Graph
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch

# Connect to Neo4j (adjust connection details as necessary)
graph = Graph("bolt://localhost:7687", auth=("neo4j", "12345678"))

# Run the Cypher query to get schema information
query = """
MATCH (n)-[r]->(m)
RETURN DISTINCT labels(n) AS source_label, type(r) AS relationship, labels(m) AS target_label
"""
results = graph.run(query).data()

# Initialize a directed graph with NetworkX
G = nx.DiGraph()

# Process the results and add nodes and edges to the graph
for record in results:
    source_label = record['source_label'][0]  # Get the first label from the list
    target_label = record['target_label'][0]  # Get the first label from the list
    relationship = record['relationship']
    
    # Add nodes and edges to the NetworkX graph
    G.add_node(source_label, label=source_label)
    G.add_node(target_label, label=target_label)
    G.add_edge(source_label, target_label, relationship=relationship)

# Draw the graph
plt.figure(figsize=(10, 10))
# which layout: spring_layout, shell_layout, random_layout, circular_layout, kamada_kawai_layout, planar_layout, spectral_layout
pos = nx.planar_layout(G)
edge_labels = {(u, v): d['relationship'] for u, v, d in G.edges(data=True)}
# nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color="red", rotate=True)
# I want big arrow heads
nx.draw_networkx_edges(G, pos, connectionstyle="arc3,rad=0.1", edge_color="black", arrowsize=10)
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color="gray", label_pos=0.4, font_size=10)
nx.draw(G, pos, with_labels=True, node_color="lightgray", node_size=5000, font_size=10, font_weight="bold", edgelist=[])

# Save and show the plot
plt.savefig("neo4j_schema_visualization.png", format="PNG")
plt.show()
